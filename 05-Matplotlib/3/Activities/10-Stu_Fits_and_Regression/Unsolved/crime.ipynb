# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import linregress

# %%
df = pd.read_csv('../Resources/crime_data.csv')
years = df['year']
crime_rate = df['violent crime rate']

(slope,inter,_,_,_,)=linregress(years,crime_rate)
fit = slope * years + inter
fit
# Out:
# 0     648.852857
# 1     633.387293
# 2     617.921729
# 3     602.456165
# 4     586.990602
# 5     571.525038
# 6     556.059474
# 7     540.593910
# 8     525.128346
# 9     509.662782
# 10    494.197218
# 11    478.731654
# 12    463.266090
# 13    447.800526
# 14    432.334962
# 15    416.869398
# 16    401.403835
# 17    385.938271
# 18    370.472707
# 19    355.007143
# Name: year, dtype: float64

# %%
fig,ax = plt.subplots()
ax.plot(years,crime_rate, marker='o')
ax.plot(years,fit, 'b--')
# Out:
# <img src="data:image/png;base64,..." width="640">
