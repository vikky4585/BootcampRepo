# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
user = api.get_user('vicky_p1')
timeline = api.user_timeline('vicky_p1')
print(timeline)
# Out:
# [{'created_at': 'Tue Aug 21 02:01:19 +0000 2018', 'id': 1031722887940657152, 'id_str': '1031722887940657152', 'text': 'RT @suhelseth: Is the DGCA asleep? Look at these vultures (other than @airvistara) and see how they are making money through the misery of…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'suhelseth', 'name': 'SUHEL SETH', 'id': 37168231, 'id_str': '37168231', 'indices': [3, 13]}, {'screen_name': 'airvistara', 'name': 'Vistara', 'id': 2491484208, 'id_str': '2491484208', 'indices': [70, 81]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 57689986, 'id_str': '57689986', 'name': 'Vikas Singh', 'screen_name': 'vicky_p1', 'location': '', 'description': 'Sports: Fernando Alonso and Kohli bhakt; Movies : Nolan bhakt', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 91, 'friends_count': 639, 'listed_count': 5, 'created_at': 'Fri Jul 17 16:42:49 +0000 2009', 'favourites_count': 2184, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2509, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/2927867453/d547f4e2951e16974ca9a225d670fd0f_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2927867453/d547f4e2951e16974ca9a225d670fd0f_normal.jpeg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Aug 19 10:01:31 +0000 2018', 'id': 1031118957510647808, 'id_str': '1031118957510647808', 'text': 'Is the DGCA asleep? Look at these vultures (other than @airvistara) and see how they are making money through the m… https://t.co/K7w9fNN7IE', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'airvistara', 'name': 'Vistara', 'id': 2491484208, 'id_str': '2491484208', 'indices': [55, 66]}], 'urls': [{'url': 'https://t.co/K7w9fNN7IE', 'expanded_url': 'https://twitter.com/i/web/status/1031118957510647808', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 37168231, 'id_str': '37168231', 'name': 'SUHEL SETH', 'screen_name': 'suhelseth', 'location': 'ÜT: 28.59669,77.191123', 'description': 'bon vivant, traveller, author, marketing maven...', 'url': 'https://t.co/qlKCFDSaOC', 'entities': {'url': {'urls': [{'url': 'https://t.co/qlKCFDSaOC', 'expanded_url': 'http://www.suhelseth.com', 'display_url': 'suhelseth.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4849148, 'friends_count': 1080, 'listed_count': 1698, 'created_at': 'Sat May 02 08:44:45 +0000 2009', 'favourites_count': 86, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 43327 ...

# %%
# Get all tweets from home feed

# %%
# Loop through all tweets
